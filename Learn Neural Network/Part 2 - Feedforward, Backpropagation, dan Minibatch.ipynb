# %% [markdown]
# <a href="https://colab.research.google.com/github/kangnurrohman/belajar-neural-network/blob/main/materi/Feedforward%2C%20Backpropagation%2C%20dan%20Minibatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install luwiji

# %%
import luwiji
luwiji.__version__

# %%
from luwiji.neural_network import illustration
from luwiji.minibatch import demo

# %% [markdown]
# ##Regression training loop

# %%
illustration.regression_loop

# %% [markdown]
# ##Neural network training loop

# %%
illustration.neural_network_loop

# %% [markdown]
# ##Minibatch

# %%
illustration.minibatch

# %%
illustration.minibatch_training

# %%
demo.gradient_descent()
# Out:
# interactive(children=(IntSlider(value=100, description='batch_size', min=1, step=5), Output()), _dom_classes=(…
