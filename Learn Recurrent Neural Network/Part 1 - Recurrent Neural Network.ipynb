# %% [markdown]
# <a href="https://colab.research.google.com/github/kangnurrohman/belajar-recurrent-neural-network/blob/main/materi/Part%201%20-%20Recurrent%20Neural%20Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install luwiji

# %%
from luwiji.rnn import illustration

# %% [markdown]
# ## Let's start with a question

# %%
illustration.wolf_husky

# %% [markdown]
# ## Sequential data provides context

# %%
illustration.context

# %% [markdown]
# ## Time series is also sequential data

# %%
illustration.input_shape

# %% [markdown]
# ## NN vs RNN

# %%
illustration.nn_vs_rnn

# %% [markdown]
# ## So here's how RNN works -> use hidden layer as memory

# %%
illustration.rnn_animation

# %% [markdown]
# ## Recurrent Neural Network (RNN)

# %%
illustration.rnn_representation

# %% [markdown]
# ## Can it use multilayer ?

# %%
illustration.multilayer

# %% [markdown]
# ## How about backprop? -> BPTT

# %%
illustration.bptt

# %% [markdown]
# ## Maths behind RNN -> Linear Combination

# %%
illustration.rnn_math
