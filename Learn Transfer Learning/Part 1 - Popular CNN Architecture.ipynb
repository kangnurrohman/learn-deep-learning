# %% [markdown]
# <a href="https://colab.research.google.com/github/kangnurrohman/belajar-transfer-learning/blob/main/materi/Part%201%20-%20Popular%20CNN%20Architecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install luwiji

# %%
from luwiji.transfer_learning import illustration

# %% [markdown]
# **ILSVRC (ImageNet Large Scale Visual Recognition Challenge)**
#
# http://www.image-net.org/challenges/LSVRC/
#
# Kompetisi object detection and image classification yang skalanya besar
# besar (misalnya ILSVRC 2017)
# *   Object classification and localization: 150000 gambar, 1000 kategori.
# *   Object detection: 200 fully labeled categories.
# *   Object detection from video: for 30 fully labeled categories.
#
# **The Good News**
#
# Banyak sekali ide-ide menarik muncul di kompetisi ILSVRC. Yang lebih menarik adalah arsitektur-arsitektur yang digunakan juga dipublikasikan, kemudian open-source, bahkan pretrained-weight dari modelnya juga diberikan.
#
# Beberapa arsitektur yang populer digunakan:

# %% [markdown]
# ## VGGNet (Runner up ILSVRC 2014)
# Idea:
#
# Compress information, increase filter

# %%
illustration.vgg16_architecture

# %%
illustration.vgg16

# %% [markdown]
# ## Inception-V3 (Runner up ILSVRC 2015) => Improvement dari GoogLeNet (Winner ILSVRC 2014)
# Idea:
#
# Inception Module

# %%
illustration.googlenet_architecture

# %%
illustration.inceptionv3_architecture

# %%
illustration.inception_module

# %% [markdown]
# ## Inception Fun Fact
# Paper Szegedy et al. (2014) cite meme ini di paper mereka => https://knowyourmeme.com/memes/we-need-to-go-deeper

# %%
illustration.go_deeper

# %% [markdown]
# ## ResNet (Winner ILSVRC 2015)
#
# Idea:
#
# Residual Block and Skip Connection

# %%
illustration.resnet34_architecture

# %%
illustration.residual_block

# %% [markdown]
# **Some notable benefit of ResNet**
# *   Handle the diminishing gradient problem
# *   Better loss landscape

# %%
illustration.resnet_loss_landscape

# %% [markdown]
# ## Some other CNN Architecture

# %%
illustration.other_cnn

# %% [markdown]
# ## Optional Reference
# This:
#
# https://towardsdatascience.com/neural-network-architectures-156e5bad51ba
#
# Warning, a little mathematics is needed for these
#
# *   https://www.youtube.com/watch?v=KfV8CJh7hE0
# *   https://www.youtube.com/watch?v=C86ZXvgpejM
# *   https://www.youtube.com/watch?v=ZILIbUvp5lk
# *   https://www.youtube.com/watch?v=RYth6EbBUqM
