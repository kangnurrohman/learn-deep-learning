# %% [markdown]
# <a href="https://colab.research.google.com/github/kangnurrohman/belajar-convolutional-neural-network/blob/main/materi/Part%202%20-%20Data%20Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install luwiji

# %%
from torchvision import transforms
from luwiji.cnn import illustration

# %% [markdown]
# **Data Augmentation**
# *   Augmentasi = merubah generality (mengurangi overfit)
# *   Menambah data

# %%
img = illustration.img
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x288 at 0x7F47F8B9AB90>

# %% [markdown]
# ## Random Crop

# %%
crop = transforms.RandomCrop(256)
crop(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7F47EEA5F350>

# %% [markdown]
# ## Random Flip

# %%
hflip = transforms.RandomHorizontalFlip()
hflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x7F47EEA7CD10>

# %%
vflip = transforms.RandomVerticalFlip()
vflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x7F47F6FB6350>

# %% [markdown]
# ## Random Rotation

# %%
rotate = transforms.RandomRotation(15)
rotate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x7F47EEA5F990>

# %% [markdown]
# ## Random ResizedCrop

# %%
resize = transforms.RandomResizedCrop(256, scale=(0.4, 1.0))
resize(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7F47EEA4CE50>

# %% [markdown]
# ## Random Affine

# %%
translate = transforms.RandomAffine(0, translate=(0.3, 0.3))
translate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x7F47EEA8A950>

# %%
shear = transforms.RandomAffine(0, shear=10)
shear(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x7F47EEFF9810>

# %%
affine = transforms.RandomAffine(5, translate=(0.1, 0.1), shear=10)
affine(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x7F47EE9A0B50>

# %% [markdown]
# ## Color Jitter

# %%
brightness = transforms.ColorJitter(brightness=0.3)
brightness(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x7F47EEA8E090>

# %%
contrast = transforms.ColorJitter(contrast=0.3)
contrast(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x7F47EEA3D3D0>
